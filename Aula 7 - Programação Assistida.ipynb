# %% [markdown]
# <a href="https://colab.research.google.com/github/guscarvalhol/engenharia_de_prompt_aplicacoes_ia/blob/main/aula07_ProgramacaoAssistida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Define a list of numbers
numeros = [1,3,6,7,8]

# Initialize a variable to store the sum
soma = 0

# Iterate through each number in the list
for num in numeros:
  # Add the current number to the sum
  soma += num

# Print the final sum
print(soma)
# Out:
# 25

# %% [markdown]
# Mini Projeto

# %% [markdown]
# Inversão de String

# %%
def inverte_text(text):
  invertido = ''
  for letra in text:
    invertido = letra + invertido

# %% [markdown]
# Eh primo

# %% [markdown]
# #Aula: Programação Assistida
